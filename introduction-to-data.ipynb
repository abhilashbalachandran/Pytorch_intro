# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
images = np.load('./images.npy')
labels = np.load('./labels.npy')

# %%
class_0_images = images[labels==0]
plt.imshow(class_0_images[0])
plt.set_cmap('gray')

# %%
class_1_images = images[labels==1]
plt.imshow(class_1_images[0])
plt.set_cmap('gray')

# %%
class_2_images = images[labels==2]
plt.imshow(class_2_images[0])
plt.set_cmap('gray')

# %%
class_3_images = images[labels==3]
plt.imshow(class_3_images[0])
plt.set_cmap('gray')

# %%
class_4_images = images[labels==4]
plt.imshow(class_4_images[0])
plt.set_cmap('gray')

# %% [markdown]
# Integer associated with:
# apple = 0;
# baseball = 1;
# Clock = 3;
# Cookie = 2;
# Fan =4;

# %%
np.shape(images)
# Out:
# (50000, 26, 26)

# %%
num_images,height,width = np.shape(images)

# %%
images = np.reshape(images,(num_images,height*width))
np.shape(images)
# Out:
# (50000, 676)

# %%
plt.plot(images[0])

# %%
plt.plot(images[1])

# %%
plt.plot(images[2])

# %%
plt.plot(images[3])

# %%
plt.plot(images[4])
